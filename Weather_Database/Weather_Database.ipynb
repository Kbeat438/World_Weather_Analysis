# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 48.42,
#   'feels_like': 46.35,
#   'temp_min': 45.28,
#   'temp_max': 51.53,
#   'pressure': 1004,
#   'humidity': 93},
#  'visibility': 9656,
#  'wind': {'speed': 5.01, 'deg': 57, 'gust': 18.01},
#  'rain': {'1h': 0.42},
#  'clouds': {'all': 90},
#  'dt': 1635345035,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1635333092,
#   'sunset': 1635371064},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
                                    
                                    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yulara
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | hamilton
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | aklavik
# Processing Record 6 of Set 1 | alofi
# Processing Record 7 of Set 1 | paamiut
# Processing Record 8 of Set 1 | svetlaya
# Processing Record 9 of Set 1 | dudinka
# Processing Record 10 of Set 1 | champerico
# Processing Record 11 of Set 1 | oktyabrskiy
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | guarapari
# Processing Record 14 of Set 1 | urubicha
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | kopyevo
# City not found. Skipping...
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | koungou
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | leh
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | podosinovets
# Processing Record 29 of Set 1 | ternate
# Processing Record 30 of Set 1 | belmonte
# Processing Record 31 of Set 1 | asau
# Processing Record 32 of Set 1 | chara
# Processing Record 33 of Set 1 | petropavlivka
# Processing Record 34 of Set 1 | sampit
# Processing Record 35 of Set 1 | timbiqui
# Processing Record 36 of Set 1 | yumen
# Processing Record 37 of Set 1 | mukhen
# Processing Record 38 of Set 1 | shush
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | touros
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | menongue
# Processing Record 45 of Set 1 | vostok
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | soe
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | atar
# Processing Record 50 of Set 1 | edd
# Processing Record 1 of Set 2 | alice springs
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | rawson
# Processing Record 4 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | mizque
# Processing Record 7 of Set 2 | laredo
# Processing Record 8 of Set 2 | beringovskiy
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | deep river
# Processing Record 14 of Set 2 | pangnirtung
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | gat
# Processing Record 17 of Set 2 | kollo
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | kismayo
# Processing Record 20 of Set 2 | clyde river
# Processing Record 21 of Set 2 | hohhot
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | broken hill
# Processing Record 24 of Set 2 | kenai
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | krasnoarmeyskiy
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | okhotsk
# Processing Record 29 of Set 2 | pacific grove
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | lamu
# Processing Record 32 of Set 2 | ombessa
# Processing Record 33 of Set 2 | nago
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | dalby
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | civitavecchia
# Processing Record 38 of Set 2 | ashbourne
# Processing Record 39 of Set 2 | araceli
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | kendari
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | rawdon
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | alashtar
# City not found. Skipping...
# Processing Record 1 of Set 3 | mataura
# Processing Record 2 of Set 3 | santiago del estero
# Processing Record 3 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | burica
# City not found. Skipping...
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | glace bay
# Processing Record 8 of Set 3 | saint-joseph
# Processing Record 9 of Set 3 | baykit
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | san quintin
# Processing Record 13 of Set 3 | karratha
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | isla vista
# Processing Record 16 of Set 3 | kudahuvadhoo
# Processing Record 17 of Set 3 | lompoc
# Processing Record 18 of Set 3 | cap malheureux
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | saint anthony
# Processing Record 21 of Set 3 | anloga
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | najran
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | san cristobal
# Processing Record 28 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 3 | adre
# Processing Record 30 of Set 3 | yali
# Processing Record 31 of Set 3 | saskylakh
# Processing Record 32 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 3 | lasa
# Processing Record 34 of Set 3 | hambantota
# Processing Record 35 of Set 3 | grindavik
# Processing Record 36 of Set 3 | naze
# Processing Record 37 of Set 3 | wenling
# Processing Record 38 of Set 3 | olafsvik
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | safakulevo
# Processing Record 41 of Set 3 | pevek
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | eyl
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | lhokseumawe
# Processing Record 48 of Set 3 | mount isa
# Processing Record 49 of Set 3 | port macquarie
# Processing Record 50 of Set 3 | haines junction
# Processing Record 1 of Set 4 | fort-shevchenko
# Processing Record 2 of Set 4 | wajima
# Processing Record 3 of Set 4 | taoudenni
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | la peca
# Processing Record 6 of Set 4 | koslan
# Processing Record 7 of Set 4 | shizunai
# Processing Record 8 of Set 4 | lexington
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 4 | vrangel
# Processing Record 12 of Set 4 | camacha
# Processing Record 13 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 4 | saint-leu
# Processing Record 15 of Set 4 | srandakan
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | zhovti vody
# Processing Record 18 of Set 4 | sao joao da barra
# Processing Record 19 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 4 | villaviciosa
# Processing Record 21 of Set 4 | tabas
# Processing Record 22 of Set 4 | saint george
# Processing Record 23 of Set 4 | cape town
# Processing Record 24 of Set 4 | hilo
# Processing Record 25 of Set 4 | sidi ali
# Processing Record 26 of Set 4 | yalvac
# Processing Record 27 of Set 4 | qui nhon
# Processing Record 28 of Set 4 | leticia
# Processing Record 29 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 4 | katobu
# Processing Record 31 of Set 4 | gravdal
# Processing Record 32 of Set 4 | jumla
# Processing Record 33 of Set 4 | tuy hoa
# Processing Record 34 of Set 4 | nishihara
# Processing Record 35 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 4 | ewa beach
# Processing Record 37 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 4 | fairbanks
# Processing Record 39 of Set 4 | batagay
# Processing Record 40 of Set 4 | buala
# Processing Record 41 of Set 4 | stryn
# Processing Record 42 of Set 4 | castro
# Processing Record 43 of Set 4 | busselton
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 4 | platanos
# Processing Record 47 of Set 4 | mabaruma
# Processing Record 48 of Set 4 | abha
# Processing Record 49 of Set 4 | gazanjyk
# Processing Record 50 of Set 4 | ancud
# Processing Record 1 of Set 5 | dicabisagan
# Processing Record 2 of Set 5 | luanda
# Processing Record 3 of Set 5 | royan
# Processing Record 4 of Set 5 | nome
# Processing Record 5 of Set 5 | micheweni
# Processing Record 6 of Set 5 | togul
# Processing Record 7 of Set 5 | coquimbo
# Processing Record 8 of Set 5 | tampakan
# Processing Record 9 of Set 5 | quatre cocos
# Processing Record 10 of Set 5 | belyy yar
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | east london
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | douentza
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 5 | victoria
# Processing Record 18 of Set 5 | hasaki
# Processing Record 19 of Set 5 | jalu
# Processing Record 20 of Set 5 | phetchaburi
# Processing Record 21 of Set 5 | dingle
# Processing Record 22 of Set 5 | akureyri
# Processing Record 23 of Set 5 | isawa
# Processing Record 24 of Set 5 | salalah
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | dharchula
# Processing Record 27 of Set 5 | kruisfontein
# Processing Record 28 of Set 5 | emba
# Processing Record 29 of Set 5 | hauterive
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 5 | half moon bay
# Processing Record 33 of Set 5 | kahului
# Processing Record 34 of Set 5 | vila velha
# Processing Record 35 of Set 5 | develi
# Processing Record 36 of Set 5 | nanpara
# Processing Record 37 of Set 5 | villa bruzual
# Processing Record 38 of Set 5 | toppenish
# Processing Record 39 of Set 5 | mindelo
# Processing Record 40 of Set 5 | milkovo
# Processing Record 41 of Set 5 | yeniseysk
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | mana
# Processing Record 44 of Set 5 | tura
# Processing Record 45 of Set 5 | anadyr
# Processing Record 46 of Set 5 | axim
# Processing Record 47 of Set 5 | nagato
# Processing Record 48 of Set 5 | thompson
# Processing Record 49 of Set 5 | qaanaaq
# Processing Record 50 of Set 5 | kudat
# Processing Record 1 of Set 6 | dongsheng
# Processing Record 2 of Set 6 | plainview
# Processing Record 3 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 6 | manono
# Processing Record 5 of Set 6 | mahebourg
# Processing Record 6 of Set 6 | ayan
# Processing Record 7 of Set 6 | laguna
# Processing Record 8 of Set 6 | elko
# Processing Record 9 of Set 6 | merauke
# Processing Record 10 of Set 6 | kovernino
# Processing Record 11 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | goderich
# Processing Record 13 of Set 6 | pedernales
# Processing Record 14 of Set 6 | mehamn
# Processing Record 15 of Set 6 | tikhmenevo
# City not found. Skipping...
# Processing Record 16 of Set 6 | severo-yeniseyskiy
# Processing Record 17 of Set 6 | toora-khem
# Processing Record 18 of Set 6 | sirsi
# Processing Record 19 of Set 6 | nuevo laredo
# Processing Record 20 of Set 6 | kaura namoda
# Processing Record 21 of Set 6 | nuuk
# Processing Record 22 of Set 6 | paracuru
# Processing Record 23 of Set 6 | skibbereen
# Processing Record 24 of Set 6 | khatanga
# Processing Record 25 of Set 6 | adrar
# Processing Record 26 of Set 6 | tokur
# Processing Record 27 of Set 6 | comodoro rivadavia
# Processing Record 28 of Set 6 | bilibino
# Processing Record 29 of Set 6 | kroonstad
# Processing Record 30 of Set 6 | cavalcante
# Processing Record 31 of Set 6 | srednekolymsk
# Processing Record 32 of Set 6 | taksimo
# Processing Record 33 of Set 6 | constitucion
# Processing Record 34 of Set 6 | antalaha
# Processing Record 35 of Set 6 | vardo
# Processing Record 36 of Set 6 | isangel
# Processing Record 37 of Set 6 | brae
# Processing Record 38 of Set 6 | buchanan
# Processing Record 39 of Set 6 | komsomolskiy
# Processing Record 40 of Set 6 | harper
# Processing Record 41 of Set 6 | pingzhuang
# Processing Record 42 of Set 6 | katherine
# Processing Record 43 of Set 6 | skjervoy
# Processing Record 44 of Set 6 | moron
# Processing Record 45 of Set 6 | manica
# Processing Record 46 of Set 6 | alanya
# Processing Record 47 of Set 6 | angarsk
# Processing Record 48 of Set 6 | tiksi
# Processing Record 49 of Set 6 | ilulissat
# Processing Record 50 of Set 6 | colares
# Processing Record 1 of Set 7 | road town
# Processing Record 2 of Set 7 | alyangula
# Processing Record 3 of Set 7 | havre-saint-pierre
# Processing Record 4 of Set 7 | samarai
# Processing Record 5 of Set 7 | high rock
# Processing Record 6 of Set 7 | broome
# Processing Record 7 of Set 7 | marawi
# Processing Record 8 of Set 7 | baker city
# Processing Record 9 of Set 7 | torbay
# Processing Record 10 of Set 7 | balmazujvaros
# Processing Record 11 of Set 7 | batavia
# Processing Record 12 of Set 7 | trairi
# Processing Record 13 of Set 7 | guerrero negro
# Processing Record 14 of Set 7 | portland
# Processing Record 15 of Set 7 | sungaipenuh
# Processing Record 16 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 7 | marienburg
# Processing Record 18 of Set 7 | hami
# Processing Record 19 of Set 7 | burnie
# Processing Record 20 of Set 7 | soc trang
# Processing Record 21 of Set 7 | bubaque
# Processing Record 22 of Set 7 | labuhan
# Processing Record 23 of Set 7 | wanning
# Processing Record 24 of Set 7 | mao
# Processing Record 25 of Set 7 | ozernovskiy
# Processing Record 26 of Set 7 | brazzaville
# Processing Record 27 of Set 7 | bulgan
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | orebro
# Processing Record 30 of Set 7 | sinnamary
# Processing Record 31 of Set 7 | lima duarte
# Processing Record 32 of Set 7 | praia da vitoria
# Processing Record 33 of Set 7 | wagar
# Processing Record 34 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 35 of Set 7 | alzamay
# Processing Record 36 of Set 7 | ahipara
# Processing Record 37 of Set 7 | saint-georges
# Processing Record 38 of Set 7 | margate
# Processing Record 39 of Set 7 | kununurra
# Processing Record 40 of Set 7 | mahanoro
# Processing Record 41 of Set 7 | moerai
# Processing Record 42 of Set 7 | yarada
# Processing Record 43 of Set 7 | herat
# Processing Record 44 of Set 7 | krnov
# Processing Record 45 of Set 7 | ahuimanu
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | mikun
# Processing Record 48 of Set 7 | monrovia
# Processing Record 49 of Set 7 | linchuan
# City not found. Skipping...
# Processing Record 50 of Set 7 | ozinki
# Processing Record 1 of Set 8 | bethel
# Processing Record 2 of Set 8 | gracias
# Processing Record 3 of Set 8 | koupela
# Processing Record 4 of Set 8 | kodiak
# Processing Record 5 of Set 8 | tautira
# Processing Record 6 of Set 8 | artesia
# Processing Record 7 of Set 8 | blue springs
# Processing Record 8 of Set 8 | drayton valley
# Processing Record 9 of Set 8 | norilsk
# Processing Record 10 of Set 8 | ko samui
# Processing Record 11 of Set 8 | robertsport
# Processing Record 12 of Set 8 | yatou
# Processing Record 13 of Set 8 | varazdin
# Processing Record 14 of Set 8 | ust-nera
# Processing Record 15 of Set 8 | filadelfia
# Processing Record 16 of Set 8 | adeje
# Processing Record 17 of Set 8 | hualmay
# Processing Record 18 of Set 8 | faya
# Processing Record 19 of Set 8 | conceicao do araguaia
# Processing Record 20 of Set 8 | rio grande
# Processing Record 21 of Set 8 | aykhal
# Processing Record 22 of Set 8 | soyo
# Processing Record 23 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 8 | husavik
# Processing Record 25 of Set 8 | bathsheba
# Processing Record 26 of Set 8 | palaiokhora
# City not found. Skipping...
# Processing Record 27 of Set 8 | karasjok
# Processing Record 28 of Set 8 | santa maria
# Processing Record 29 of Set 8 | lubao
# Processing Record 30 of Set 8 | lahat
# Processing Record 31 of Set 8 | igarka
# Processing Record 32 of Set 8 | north fort myers
# Processing Record 33 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 8 | takoradi
# Processing Record 35 of Set 8 | paita
# Processing Record 36 of Set 8 | socorro
# Processing Record 37 of Set 8 | methoni
# Processing Record 38 of Set 8 | san policarpo
# Processing Record 39 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 8 | pemba
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | lata
# Processing Record 44 of Set 8 | coihaique
# Processing Record 45 of Set 8 | grand gaube
# Processing Record 46 of Set 8 | yar-sale
# Processing Record 47 of Set 8 | nauta
# Processing Record 48 of Set 8 | serenje
# Processing Record 49 of Set 8 | leningradskiy
# Processing Record 50 of Set 8 | gobabis
# Processing Record 1 of Set 9 | port lincoln
# Processing Record 2 of Set 9 | erenhot
# Processing Record 3 of Set 9 | nemuro
# Processing Record 4 of Set 9 | ouadda
# Processing Record 5 of Set 9 | baijiantan
# Processing Record 6 of Set 9 | roald
# Processing Record 7 of Set 9 | bandarbeyla
# Processing Record 8 of Set 9 | noumea
# Processing Record 9 of Set 9 | mackay
# Processing Record 10 of Set 9 | ostrovnoy
# Processing Record 11 of Set 9 | klaksvik
# Processing Record 12 of Set 9 | ormara
# Processing Record 13 of Set 9 | altay
# Processing Record 14 of Set 9 | sumbe
# Processing Record 15 of Set 9 | anito
# Processing Record 16 of Set 9 | the pas
# Processing Record 17 of Set 9 | lowestoft
# Processing Record 18 of Set 9 | hoshcha
# Processing Record 19 of Set 9 | yelizovo
# Processing Record 20 of Set 9 | mayskiy
# Processing Record 21 of Set 9 | biryusinsk
# Processing Record 22 of Set 9 | sobolevo
# Processing Record 23 of Set 9 | acapulco
# Processing Record 24 of Set 9 | moree
# Processing Record 25 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 9 | pangody
# Processing Record 27 of Set 9 | lufilufi
# Processing Record 28 of Set 9 | rivadavia
# Processing Record 29 of Set 9 | camapua
# Processing Record 30 of Set 9 | sturgis
# Processing Record 31 of Set 9 | daru
# Processing Record 32 of Set 9 | mayo
# Processing Record 33 of Set 9 | myitkyina
# Processing Record 34 of Set 9 | katsuura
# Processing Record 35 of Set 9 | suluq
# Processing Record 36 of Set 9 | huarmey
# Processing Record 37 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 38 of Set 9 | waipawa
# Processing Record 39 of Set 9 | tongchuan
# Processing Record 40 of Set 9 | itaituba
# Processing Record 41 of Set 9 | port augusta
# Processing Record 42 of Set 9 | juneau
# Processing Record 43 of Set 9 | hirara
# Processing Record 44 of Set 9 | umm lajj
# Processing Record 45 of Set 9 | carndonagh
# Processing Record 46 of Set 9 | porto novo
# Processing Record 47 of Set 9 | gander
# Processing Record 48 of Set 9 | manzanillo
# Processing Record 49 of Set 9 | kathu
# Processing Record 50 of Set 9 | ordu
# Processing Record 1 of Set 10 | havoysund
# Processing Record 2 of Set 10 | lucban
# Processing Record 3 of Set 10 | soure
# Processing Record 4 of Set 10 | tayga
# Processing Record 5 of Set 10 | aitape
# Processing Record 6 of Set 10 | sept-iles
# Processing Record 7 of Set 10 | artigas
# Processing Record 8 of Set 10 | darnah
# Processing Record 9 of Set 10 | tuatapere
# Processing Record 10 of Set 10 | riberalta
# Processing Record 11 of Set 10 | novovelichkovskaya
# Processing Record 12 of Set 10 | port hardy
# Processing Record 13 of Set 10 | erzin
# Processing Record 14 of Set 10 | kiama
# Processing Record 15 of Set 10 | yuci
# Processing Record 16 of Set 10 | mecca
# Processing Record 17 of Set 10 | emerald
# Processing Record 18 of Set 10 | ceuta
# Processing Record 19 of Set 10 | grand forks
# Processing Record 20 of Set 10 | chapais
# Processing Record 21 of Set 10 | murgab
# Processing Record 22 of Set 10 | sandwick
# Processing Record 23 of Set 10 | mesopotamia
# Processing Record 24 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 25 of Set 10 | rio muerto
# Processing Record 26 of Set 10 | clarence town
# Processing Record 27 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 10 | klyuchi
# Processing Record 29 of Set 10 | waingapu
# Processing Record 30 of Set 10 | gunjur
# Processing Record 31 of Set 10 | palmer
# Processing Record 32 of Set 10 | cacequi
# Processing Record 33 of Set 10 | moindou
# Processing Record 34 of Set 10 | amudat
# Processing Record 35 of Set 10 | vradiyivka
# Processing Record 36 of Set 10 | gorontalo
# Processing Record 37 of Set 10 | kisanga
# Processing Record 38 of Set 10 | hobyo
# Processing Record 39 of Set 10 | bikaner
# Processing Record 40 of Set 10 | sapa
# Processing Record 41 of Set 10 | honiara
# Processing Record 42 of Set 10 | vallenar
# Processing Record 43 of Set 10 | los llanos de aridane
# Processing Record 44 of Set 10 | zabol
# Processing Record 45 of Set 10 | kashi
# Processing Record 46 of Set 10 | parati
# Processing Record 47 of Set 10 | mitchell
# Processing Record 48 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 49 of Set 10 | megion
# Processing Record 50 of Set 10 | noshiro
# Processing Record 1 of Set 11 | kang
# Processing Record 2 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 11 | kamaishi
# Processing Record 4 of Set 11 | launceston
# Processing Record 5 of Set 11 | hokitika
# Processing Record 6 of Set 11 | nizhneshilovka
# City not found. Skipping...
# Processing Record 7 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 11 | bonthe
# Processing Record 9 of Set 11 | sembakung
# Processing Record 10 of Set 11 | shangzhi
# Processing Record 11 of Set 11 | cairns
# Processing Record 12 of Set 11 | candolim
# Processing Record 13 of Set 11 | puerto carreno
# Processing Record 14 of Set 11 | ingham
# Processing Record 15 of Set 11 | nefteyugansk
# Processing Record 16 of Set 11 | bayeux
# Processing Record 17 of Set 11 | kostyantynivka
# Processing Record 18 of Set 11 | ludvika
# Processing Record 19 of Set 11 | isabela
# Processing Record 20 of Set 11 | neijiang
# Processing Record 21 of Set 11 | beloha
# Processing Record 22 of Set 11 | praya
# Processing Record 23 of Set 11 | santa cruz del sur
# Processing Record 24 of Set 11 | moroni
# Processing Record 25 of Set 11 | bournemouth
# Processing Record 26 of Set 11 | kungurtug
# Processing Record 27 of Set 11 | linhares
# Processing Record 28 of Set 11 | bonavista
# Processing Record 29 of Set 11 | nantucket
# Processing Record 30 of Set 11 | saint-pierre
# Processing Record 31 of Set 11 | kardla
# Processing Record 32 of Set 11 | elumalai
# Processing Record 33 of Set 11 | annavasal
# Processing Record 34 of Set 11 | la ronge
# Processing Record 35 of Set 11 | spassk-ryazanskiy
# Processing Record 36 of Set 11 | inhambane
# Processing Record 37 of Set 11 | basoko
# Processing Record 38 of Set 11 | warri
# Processing Record 39 of Set 11 | riyadh
# Processing Record 40 of Set 11 | tiarei
# Processing Record 41 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 42 of Set 11 | matagami
# Processing Record 43 of Set 11 | taguatinga
# Processing Record 44 of Set 11 | lewistown
# Processing Record 45 of Set 11 | pemberton
# Processing Record 46 of Set 11 | santiago
# Processing Record 47 of Set 11 | natal
# Processing Record 48 of Set 11 | rio gallegos
# Processing Record 49 of Set 11 | meulaboh
# Processing Record 50 of Set 11 | stornoway
# Processing Record 1 of Set 12 | tuusula
# Processing Record 2 of Set 12 | taltal
# Processing Record 3 of Set 12 | borogontsy
# Processing Record 4 of Set 12 | uddevalla
# Processing Record 5 of Set 12 | abalak
# Processing Record 6 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 12 | seymchan
# Processing Record 8 of Set 12 | vila franca do campo
# Processing Record 9 of Set 12 | steinbach
# Processing Record 10 of Set 12 | moose factory
# Processing Record 11 of Set 12 | caohai
# Processing Record 12 of Set 12 | roswell
# Processing Record 13 of Set 12 | juana diaz
# Processing Record 14 of Set 12 | bom jesus do galho
# Processing Record 15 of Set 12 | lakes entrance
# Processing Record 16 of Set 12 | myrtle beach
# Processing Record 17 of Set 12 | wake forest
# Processing Record 18 of Set 12 | kavaratti
# Processing Record 19 of Set 12 | southbridge
# Processing Record 20 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 12 | iki-burul
# Processing Record 22 of Set 12 | sao jose da coroa grande
# Processing Record 23 of Set 12 | olonets
# Processing Record 24 of Set 12 | guiratinga
# Processing Record 25 of Set 12 | dumas
# Processing Record 26 of Set 12 | cangzhou
# Processing Record 27 of Set 12 | inuvik
# Processing Record 28 of Set 12 | hovd
# Processing Record 29 of Set 12 | san andres
# Processing Record 30 of Set 12 | rongcheng
# Processing Record 31 of Set 12 | thohoyandou
# Processing Record 32 of Set 12 | bestobe
# Processing Record 33 of Set 12 | tygda
# Processing Record 34 of Set 12 | lagoa santa
# Processing Record 35 of Set 12 | chabahar
# Processing Record 36 of Set 12 | jiwani
# Processing Record 37 of Set 12 | tagusao
# Processing Record 38 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 12 | hofn
# Processing Record 40 of Set 12 | mudu
# Processing Record 41 of Set 12 | xiongshi
# City not found. Skipping...
# Processing Record 42 of Set 12 | vestmannaeyjar
# Processing Record 43 of Set 12 | penzance
# Processing Record 44 of Set 12 | nizwa
# Processing Record 45 of Set 12 | deputatskiy
# Processing Record 46 of Set 12 | sakakah
# Processing Record 47 of Set 12 | puerto rondon
# Processing Record 48 of Set 12 | aripuana
# Processing Record 49 of Set 12 | puerto del rosario
# Processing Record 50 of Set 12 | sao felix do xingu
# Processing Record 1 of Set 13 | peace river
# Processing Record 2 of Set 13 | arman
# Processing Record 3 of Set 13 | londoko
# Processing Record 4 of Set 13 | cockburn town
# Processing Record 5 of Set 13 | valparaiso
# Processing Record 6 of Set 13 | ukiah
# Processing Record 7 of Set 13 | senneterre
# Processing Record 8 of Set 13 | ode
# Processing Record 9 of Set 13 | ixtapa
# Processing Record 10 of Set 13 | mae sai
# Processing Record 11 of Set 13 | hay river
# Processing Record 12 of Set 13 | sargur
# Processing Record 13 of Set 13 | zhigansk
# Processing Record 14 of Set 13 | las matas de farfan
# Processing Record 15 of Set 13 | along
# Processing Record 16 of Set 13 | paris
# Processing Record 17 of Set 13 | alamogordo
# Processing Record 18 of Set 13 | nyurba
# Processing Record 19 of Set 13 | necochea
# Processing Record 20 of Set 13 | lichinga
# Processing Record 21 of Set 13 | yutsa
# Processing Record 22 of Set 13 | mitsamiouli
# Processing Record 23 of Set 13 | matay
# Processing Record 24 of Set 13 | sioux lookout
# Processing Record 25 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 13 | san patricio
# Processing Record 27 of Set 13 | lacombe
# Processing Record 28 of Set 13 | villanueva
# Processing Record 29 of Set 13 | boysun
# Processing Record 30 of Set 13 | nara
# Processing Record 31 of Set 13 | krasnozatonskiy
# Processing Record 32 of Set 13 | mareeba
# Processing Record 33 of Set 13 | sur
# Processing Record 34 of Set 13 | yinchuan
# Processing Record 35 of Set 13 | sirnak
# Processing Record 36 of Set 13 | teknaf
# Processing Record 37 of Set 13 | durusu
# Processing Record 38 of Set 13 | minatitlan
# Processing Record 39 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 13 | shihezi
# Processing Record 41 of Set 13 | kurmanayevka
# Processing Record 42 of Set 13 | gariaband
# Processing Record 43 of Set 13 | waddan
# Processing Record 44 of Set 13 | oyo
# Processing Record 45 of Set 13 | pirgos
# Processing Record 46 of Set 13 | nioro
# Processing Record 47 of Set 13 | vanavara
# Processing Record 48 of Set 13 | tarko-sale
# Processing Record 49 of Set 13 | padang
# Processing Record 50 of Set 13 | cantagallo
# Processing Record 1 of Set 14 | zhuhai
# Processing Record 2 of Set 14 | krasnyy kut
# Processing Record 3 of Set 14 | manggar
# Processing Record 4 of Set 14 | sovetskaya
# Processing Record 5 of Set 14 | dargaville
# Processing Record 6 of Set 14 | wichian buri
# Processing Record 7 of Set 14 | ardesen
# Processing Record 8 of Set 14 | qasigiannguit
# Processing Record 9 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 14 | alto araguaia
# Processing Record 11 of Set 14 | mnogovershinnyy
# Processing Record 12 of Set 14 | longyearbyen
# Processing Record 13 of Set 14 | koundara
# Processing Record 14 of Set 14 | tamiahua
# Processing Record 15 of Set 14 | redcliffe
# Processing Record 16 of Set 14 | phangnga
# Processing Record 17 of Set 14 | vestmanna
# Processing Record 18 of Set 14 | conchas
# Processing Record 19 of Set 14 | kutulik
# Processing Record 20 of Set 14 | maceio
# Processing Record 21 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 22 of Set 14 | bayan
# Processing Record 23 of Set 14 | torbat-e jam
# Processing Record 24 of Set 14 | namatanai
# Processing Record 25 of Set 14 | wad madani
# Processing Record 26 of Set 14 | zaysan
# Processing Record 27 of Set 14 | linxia
# Processing Record 28 of Set 14 | coos bay
# Processing Record 29 of Set 14 | north reading
# Processing Record 30 of Set 14 | birao
# Processing Record 31 of Set 14 | los andes
# Processing Record 32 of Set 14 | barberton
# Processing Record 33 of Set 14 | havelian
# Processing Record 34 of Set 14 | timra
# Processing Record 35 of Set 14 | opuwo
# Processing Record 36 of Set 14 | ghanzi
# Processing Record 37 of Set 14 | new london
# Processing Record 38 of Set 14 | seminole
# Processing Record 39 of Set 14 | catuday
# Processing Record 40 of Set 14 | narkevychi
# Processing Record 41 of Set 14 | eirunepe
# Processing Record 42 of Set 14 | chippewa falls
# Processing Record 43 of Set 14 | rognan
# Processing Record 44 of Set 14 | saucillo
# Processing Record 45 of Set 14 | poretskoye
# Processing Record 46 of Set 14 | yartsevo
# Processing Record 47 of Set 14 | zapolyarnyy
# Processing Record 48 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 14 | uvarovka
# Processing Record 50 of Set 14 | evensk
# Processing Record 1 of Set 15 | iracoubo
# Processing Record 2 of Set 15 | west wendover
# Processing Record 3 of Set 15 | trapani
# Processing Record 4 of Set 15 | memmingen
# Processing Record 5 of Set 15 | istra
# Processing Record 6 of Set 15 | radomsko
# Processing Record 7 of Set 15 | santa rosa
# Processing Record 8 of Set 15 | lianzhou
# Processing Record 9 of Set 15 | swan river
# Processing Record 10 of Set 15 | ilanskiy
# Processing Record 11 of Set 15 | tulum
# Processing Record 12 of Set 15 | alta floresta
# Processing Record 13 of Set 15 | amapa
# Processing Record 14 of Set 15 | santo andre
# Processing Record 15 of Set 15 | tazovskiy
# Processing Record 16 of Set 15 | barabai
# Processing Record 17 of Set 15 | kirakira
# Processing Record 18 of Set 15 | hakkari
# Processing Record 19 of Set 15 | azad shahr
# Processing Record 20 of Set 15 | kota belud
# Processing Record 21 of Set 15 | sabang
# Processing Record 22 of Set 15 | otavi
# Processing Record 23 of Set 15 | richards bay
# Processing Record 24 of Set 15 | kasama
# Processing Record 25 of Set 15 | olga
# Processing Record 26 of Set 15 | humaita
# Processing Record 27 of Set 15 | shahdadkot
# Processing Record 28 of Set 15 | brownwood
# Processing Record 29 of Set 15 | kattivakkam
# Processing Record 30 of Set 15 | coahuayana
# Processing Record 31 of Set 15 | lengshuijiang
# Processing Record 32 of Set 15 | wanaka
# Processing Record 33 of Set 15 | poum
# Processing Record 34 of Set 15 | rurrenabaque
# Processing Record 35 of Set 15 | belaya gora
# Processing Record 36 of Set 15 | nouadhibou
# Processing Record 37 of Set 15 | velingara
# Processing Record 38 of Set 15 | beidao
# Processing Record 39 of Set 15 | goiania
# Processing Record 40 of Set 15 | talavera
# Processing Record 41 of Set 15 | wukari
# Processing Record 42 of Set 15 | sogdiondon
# City not found. Skipping...
# Processing Record 43 of Set 15 | alexandria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_column_order = ["City", "Country", "Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order]
city_data_df
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0        Yulara      AU  2021-10-27 14:59:23 -25.2406  130.9889     76.84
# 1    Bredasdorp      ZA  2021-10-27 14:59:23 -34.5322   20.0403     76.28
# 2      Hamilton      US  2021-10-27 14:58:52  39.1834  -84.5333     50.99
# 3    Butaritari      KI  2021-10-27 14:59:24   3.0707  172.7902     82.29
# 4       Aklavik      CA  2021-10-27 14:59:24  68.2191 -135.0107     27.32
# ..          ...     ...                  ...      ...       ...       ...
# 688      Beidao      CN  2021-10-27 15:03:50  34.5686  105.8933     48.85
# 689     Goiania      BR  2021-10-27 15:01:21 -16.6786  -49.2539     82.99
# 690    Talavera      PH  2021-10-27 15:03:50  15.6167  120.9333     74.64
# 691      Wukari      NG  2021-10-27 15:03:50   7.8500    9.7833     89.31
# 692  Alexandria      EG  2021-10-27 15:02:44  31.2156   29.9553     75.83
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          22          67        0.00       broken clouds
# 1          80         100       15.68          light rain
# 2          81          66        1.01       broken clouds
# 3          72         100       13.58          light rain
# 4          95         100        5.35     overcast clouds
# ..        ...         ...         ...                 ...
# 688        88         100        1.05     overcast clouds
# 689        54          98        6.20     overcast clouds
# 690        90          61        2.53       broken clouds
# 691        55          73        3.65       broken clouds
# 692        69          77       17.18       broken clouds
#
# [693 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
